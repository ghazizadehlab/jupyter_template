# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
#
# + List popular languages for Data Science
# + List commonly used libraries in Data Science
# + Play with Markdown
# + show example of simple arithmetics in python
#
# ## Author
# Ali Ghazizadeh

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. scikitlearn
# 2. Pandas
# 3. numpy

# %% [markdown]
# |Data Science Tools|
# |----------|
# |Jupyter Notebook|
# |Rstudio|
# |VScode|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# **print('addition: 3+2=',3+2, '\t subtraction: 3-2=',3-2,'\t multiplication:3*2=',3*2,'\t division:3/2=',3/2,'\t power:3^2=',3\*\*2)**
#
# <u>_will print:_</u>
#
# __addition: 3+2= 5 	 subtraction: 3-2= 1 	 multiplication:3*2= 6 	 division:3/2= 1.5 	 power:3^2= 9__

# %%
print('\033[1maddition: 3+2=',3+2, '\t subtraction: 3-2=',3-2,'\t multiplication:3*2=',3*2,'\t division:3/2=',3/2,'\t power:3^2=',3**2)
# Out:
#  addition: 3+2= 5 	 subtraction: 3-2= 1 	 multiplication:3*2= 6 	 division:3/2= 1.5 	 power:3^2= 9

# %%
 '''This a simple arithmetic expression to mutiply then add integers'''
print('\033[1m (3*4)+5=',(3*4)+5)
# Out:
#  (3*4)+5= 17

# %%
'''This will convert 200 minutes to hours by diving by 60'''
mins=200;mins_in_hour=60
print(f"There are {mins/mins_in_hour:.1f} hours in {mins} minutes")
# Out:
# There are 3.3 hours in 200 minutes
